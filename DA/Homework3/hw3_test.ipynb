# %%
#goog = (read.csv('GOOG.CSV'))
#head(goog)

# goog = read.csv('GOOG.CSV')
# head(goog)
 fb = read.csv('FB.CSV')
# head(fb)
 msft = read.csv('MSFT.CSV')
 #head(msft)
 amzn = read.csv('AMZN.CSV')
 #head(amzn)
 aapl = read.csv('AAPL.CSV')
# head(aapl)

# %%
#nrow(ibm)
#ibm[-1,5]

# %%
closeratio  <- aapl[-nrow(aapl),5] / aapl[-1,5]

#closeratio
#length(closeratio)

aapl$close_ratio = c(NA,closeratio)
#ibm$close_ratio = round(ibm$close_ratio,6)

head(aapl)
tail(aapl)
# Out:
#   Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 1 2018-01-02 42.5400 43.0750 42.3150 43.0650 41.51358  102223600        NA
# 2 2018-01-03 43.1325 43.6375 42.9900 43.0575 41.50634  118071600 1.0001742
# 3 2018-01-04 43.1350 43.3675 43.0200 43.2575 41.69914   89738400 0.9953765
# 4 2018-01-05 43.3600 43.8425 43.2625 43.7500 42.17389   94640000 0.9887429
# 5 2018-01-08 43.5875 43.9025 43.4825 43.5875 42.01725   82271200 1.0037281
# 6 2018-01-09 43.6375 43.7650 43.3525 43.5825 42.01243   86336000 1.0001148
#     Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 245 2018-12-20 40.1000 40.5275 38.8250 39.2075 38.36247  259092000 1.0258879
# 246 2018-12-21 39.2150 39.5400 37.4075 37.6825 36.87033  382978400 1.0404697
# 247 2018-12-24 37.0375 37.8875 36.6475 36.7075 35.91636  148676800 1.0265613
# 248 2018-12-26 37.0750 39.3075 36.6800 39.2925 38.44564  234330000 0.9342114
# ...

# %%
adj_close_ratio  <- aapl[-nrow(aapl),6] / aapl[-1,6]

#adj_close_ratio
#length(adj_close_ratio)

aapl$adj_close_ratio = c(NA,adj_close_ratio)
#ibm$adj_close_ratio = round(ibm$adj_close_ratio,6)

head(aapl)
tail(aapl)
# Out:
#   Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 1 2018-01-02 42.5400 43.0750 42.3150 43.0650 41.51358  102223600        NA
# 2 2018-01-03 43.1325 43.6375 42.9900 43.0575 41.50634  118071600 1.0001742
# 3 2018-01-04 43.1350 43.3675 43.0200 43.2575 41.69914   89738400 0.9953765
# 4 2018-01-05 43.3600 43.8425 43.2625 43.7500 42.17389   94640000 0.9887429
# 5 2018-01-08 43.5875 43.9025 43.4825 43.5875 42.01725   82271200 1.0037281
# 6 2018-01-09 43.6375 43.7650 43.3525 43.5825 42.01243   86336000 1.0001148
#   adj_close_ratio
# 1        NA
# 2 1.0001743
# 3 0.9953765
# 4 0.9887429
# 5 1.0037280
# 6 1.0001148
#     Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 245 2018-12-20 40.1000 40.5275 38.8250 39.2075 38.36247  259092000 1.0258879
# 246 2018-12-21 39.2150 39.5400 37.4075 37.6825 36.87033  382978400 1.0404697
# 247 2018-12-24 37.0375 37.8875 36.6475 36.7075 35.91636  148676800 1.0265613
# ...

# %%
aapl$diff_ratio = aapl[,8] - aapl[,9]
head(aapl)
tail(aapl)
# Out:
#   Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 1 2018-01-02 42.5400 43.0750 42.3150 43.0650 41.51358  102223600        NA
# 2 2018-01-03 43.1325 43.6375 42.9900 43.0575 41.50634  118071600 1.0001742
# 3 2018-01-04 43.1350 43.3675 43.0200 43.2575 41.69914   89738400 0.9953765
# 4 2018-01-05 43.3600 43.8425 43.2625 43.7500 42.17389   94640000 0.9887429
# 5 2018-01-08 43.5875 43.9025 43.4825 43.5875 42.01725   82271200 1.0037281
# 6 2018-01-09 43.6375 43.7650 43.3525 43.5825 42.01243   86336000 1.0001148
#   adj_close_ratio diff_ratio
# 1        NA                  NA
# 2 1.0001743       -1.491097e-07
# 3 0.9953765       -2.205712e-08
# 4 0.9887429       -8.389889e-08
# 5 1.0037280        1.184949e-07
# 6 1.0001148       -4.713328e-09
#     Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 245 2018-12-20 40.1000 40.5275 38.8250 39.2075 38.36247  259092000 1.0258879
# ...

# %%
aapl$dividend = aapl[,5]*aapl[,10]
aapl
# Out:
#     Date       Open    High    Low     Close   Adj.Close Volume    close_ratio
# 1   2018-01-02 42.5400 43.0750 42.3150 43.0650 41.51358  102223600        NA
# 2   2018-01-03 43.1325 43.6375 42.9900 43.0575 41.50634  118071600 1.0001742
# 3   2018-01-04 43.1350 43.3675 43.0200 43.2575 41.69914   89738400 0.9953765
# 4   2018-01-05 43.3600 43.8425 43.2625 43.7500 42.17389   94640000 0.9887429
# 5   2018-01-08 43.5875 43.9025 43.4825 43.5875 42.01725   82271200 1.0037281
# 6   2018-01-09 43.6375 43.7650 43.3525 43.5825 42.01243   86336000 1.0001148
# 7   2018-01-10 43.2900 43.5750 43.2500 43.5725 42.00280   95839600 1.0002295
# 8   2018-01-11 43.6475 43.8725 43.6225 43.8200 42.24138   74670800 0.9943518
# 9   2018-01-12 44.0450 44.3400 43.9125 44.2725 42.67758  101672400 0.9897792
# 10  2018-01-16 44.4750 44.8475 44.0350 44.0475 42.46069  118263600 1.0051081
# 11  2018-01-17 44.0375 44.8125 43.7675 44.7750 43.16198  137547200 0.9837521
# ...

# %%
finalg <- aapl[aapl$diff_ratio >=0.0001,] # 5 zero
finalg  <-  finalg[c('Date','dividend')]
finalg
# Out:
#     Date       dividend
# NA  NA                NA
# 28  2018-02-09 0.1574937
# 91  2018-05-11 0.1825018
# 154 2018-08-10 0.1824938
# 217 2018-11-08 0.1824986

# %%
#summary(ibm$dividend == 0)
